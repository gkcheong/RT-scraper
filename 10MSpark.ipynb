# %%
# %load_ext autoreload
# %autoreload 2

import pyspark as pys
from pyspark.sql.types import *
from pyspark.sql.functions import *

# %%
sc = pys.sql.SparkSession.builder.appName('filter_movielens').master('local[4]').getOrCreate()


movieSchema = StructType([StructField('MovieId',IntegerType()), \
                          StructField('Title', StringType()),   \
                          StructField('Genres', StringType())])

ratingSchema = StructType([StructField('UserId',IntegerType()),  \
                           StructField('MovieId',IntegerType()),  \
                           StructField('Rating', FloatType()),    \
                           StructField('Timestamp', TimestampType())])

#read as text first
movieText = sc.read.text('ml-10m/ml-10M100K/movies.dat')
movieText.select(split(movieText['value'],'::')).show()
# Out:
# +--------------------+
# |    split(value, ::)|
# +--------------------+
# |[1, Toy Story (19...|
# |[2, Jumanji (1995...|
# |[3, Grumpier Old ...|
# |[4, Waiting to Ex...|
# |[5, Father of the...|
# |[6, Heat (1995), ...|
# |[7, Sabrina (1995...|
# |[8, Tom and Huck ...|
# |[9, Sudden Death ...|
# |[10, GoldenEye (1...|
# |[11, American Pre...|
# |[12, Dracula: Dea...|
# |[13, Balto (1995)...|
# |[14, Nixon (1995)...|
# |[15, Cutthroat Is...|
# |[16, Casino (1995...|
# |[17, Sense and Se...|
# |[18, Four Rooms (...|
# |[19, Ace Ventura:...|
# |[20, Money Train ...|
# +--------------------+
# only showing top 20 rows

# %%
rddc = sc.sparkContext
movieLines = rddc.textFile('ml-10m/ml-10M100K/movies.dat')

# %%
movieParsed = movieLines.map(lambda l : l.split(sep='::'))

# %%
movies = sc.createDataFrame(movieParsed, schema = ['MovieId', 'Title', 'Genres'])
movies
# Out:
# DataFrame[MovieId: string, Title: string, Genres: string]

# %%
movies = movies.withColumn('MovieId', movies['MovieId'].cast(IntegerType()))

# %%
movies
movies.show()
# Out:
# +-------+--------------------+--------------------+
# |MovieId|               Title|              Genres|
# +-------+--------------------+--------------------+
# |      1|    Toy Story (1995)|Adventure|Animati...|
# |      2|      Jumanji (1995)|Adventure|Childre...|
# |      3|Grumpier Old Men ...|      Comedy|Romance|
# |      4|Waiting to Exhale...|Comedy|Drama|Romance|
# |      5|Father of the Bri...|              Comedy|
# |      6|         Heat (1995)|Action|Crime|Thri...|
# |      7|      Sabrina (1995)|      Comedy|Romance|
# |      8| Tom and Huck (1995)|  Adventure|Children|
# |      9| Sudden Death (1995)|              Action|
# |     10|    GoldenEye (1995)|Action|Adventure|...|
# |     11|American Presiden...|Comedy|Drama|Romance|
# |     12|Dracula: Dead and...|       Comedy|Horror|
# |     13|        Balto (1995)|  Animation|Children|
# |     14|        Nixon (1995)|               Drama|
# |     15|Cutthroat Island ...|Action|Adventure|...|
# |     16|       Casino (1995)|         Crime|Drama|
# |     17|Sense and Sensibi...|Comedy|Drama|Romance|
# |     18|   Four Rooms (1995)|Comedy|Drama|Thri...|
# |     19|Ace Ventura: When...|              Comedy|
# |     20|  Money Train (1995)|Action|Comedy|Cri...|
# +-------+--------------------+--------------------+
# only showing top 20 rows

# %%
#load ratings
ratingLines = rddc.textFile('ml-10m/ml-10M100K/ratings.dat')
#split lines
ratingParsed = ratingLines.map(lambda l : l.split(sep='::'))
ratings = sc.createDataFrame(ratingParsed, schema = ['UserId', 'MovieId', 'Rating', 'Timestamp'])
ratings.show()
ratings
# Out:
# +------+-------+------+---------+
# |UserId|MovieId|Rating|Timestamp|
# +------+-------+------+---------+
# |     1|    122|     5|838985046|
# |     1|    185|     5|838983525|
# |     1|    231|     5|838983392|
# |     1|    292|     5|838983421|
# |     1|    316|     5|838983392|
# |     1|    329|     5|838983392|
# |     1|    355|     5|838984474|
# |     1|    356|     5|838983653|
# |     1|    362|     5|838984885|
# |     1|    364|     5|838983707|
# |     1|    370|     5|838984596|
# |     1|    377|     5|838983834|
# |     1|    420|     5|838983834|
# |     1|    466|     5|838984679|
# |     1|    480|     5|838983653|
# |     1|    520|     5|838984679|
# |     1|    539|     5|838984068|
# |     1|    586|     5|838984068|
# |     1|    588|     5|838983339|
# |     1|    589|     5|838983778|
# +------+-------+------+---------+
# only showing top 20 rows
# DataFrame[UserId: string, MovieId: string, Rating: string, Timestamp: string]

# %%
ratings = ratings.withColumn('UserId', ratings['UserId'].cast(IntegerType()))
ratings = ratings.withColumn('MovieId', ratings['MovieId'].cast(IntegerType()))
ratings = ratings.withColumn('Rating', ratings['Rating'].cast(FloatType()))
ratings
ratings.show()
# Out:
# +------+-------+------+---------+
# |UserId|MovieId|Rating|Timestamp|
# +------+-------+------+---------+
# |     1|    122|   5.0|838985046|
# |     1|    185|   5.0|838983525|
# |     1|    231|   5.0|838983392|
# |     1|    292|   5.0|838983421|
# |     1|    316|   5.0|838983392|
# |     1|    329|   5.0|838983392|
# |     1|    355|   5.0|838984474|
# |     1|    356|   5.0|838983653|
# |     1|    362|   5.0|838984885|
# |     1|    364|   5.0|838983707|
# |     1|    370|   5.0|838984596|
# |     1|    377|   5.0|838983834|
# |     1|    420|   5.0|838983834|
# |     1|    466|   5.0|838984679|
# |     1|    480|   5.0|838983653|
# |     1|    520|   5.0|838984679|
# |     1|    539|   5.0|838984068|
# |     1|    586|   5.0|838984068|
# |     1|    588|   5.0|838983339|
# |     1|    589|   5.0|838983778|
# +------+-------+------+---------+
# only showing top 20 rows

# %%
ppdRatings = ratings.groupBy('MovieId').agg({'Rating' : 'avg'}).withColumnRenamed('avg(Rating)','Rating')
#ppdRatings.show() #can be optimized

# %%
filteredRatings = ppdRatings.join(movies, ppdRatings.MovieId == movies.MovieId, 'inner').select(movies.Title, ppdRatings.Rating)
#ppdRatings.show()
filteredRatings.first()
# Out:
# Row(Title='Awfully Big Adventure, An (1995)', Rating=2.8797468354430378)

# %%
filteredRatings.createOrReplaceTempView('ratings')
# Out:
# +-----+------+
# |Title|Rating|
# +-----+------+
# +-----+------+

# %%
sqlDF = sc.sql("SELECT * FROM ratings WHERE Title LIKE 'August Rush%'")
sqlDF.show()
# Out:
# +------------------+-----------------+
# |             Title|           Rating|
# +------------------+-----------------+
# |August Rush (2007)|3.476878612716763|
# +------------------+-----------------+

# %%
import pandas as pd

scrappedData = pd.read_pickle('all_data.pkl')
print(scrappedData)
# Out:
#                                    name audience critics          date  \
# 0              children_of_a_lesser_god       79      81   Oct 3, 1986
# 1                            changeland       66      63   Jun 7, 2019
# 2                    japanese_war_bride     None    None  Jan 29, 1952
# 3                                8_mile       54      75   Nov 8, 2002
# 4                                 ted_2       50      45  Jun 26, 2015
# ...                                 ...      ...     ...           ...
# 4494                  two_english_girls       82      86  Oct 15, 1972
# 4495                      3_generations       44      32   May 5, 2017
# 4496                    prometheus_2012       68      73   Jun 8, 2012
# 4497                      mrs_doubtfire       77      72  Nov 24, 1993
# 4498  national_treasure_book_of_secrets       67      36  Dec 21, 2007
#
#                                                   genre             director
# 0       [Drama, Musical &amp; Performing Arts, Romance]       [Randa Haines]
# 1                                       [Comedy, Drama]         [Seth Green]
# 2                                     [Classics, Drama]         [King Vidor]
# 3                                               [Drama]      [Curtis Hanson]
# 4                                              [Comedy]    [Seth MacFarlane]
# ...                                                 ...                  ...
# 4494  [Art House &amp; International, Documentary, D...  [François Truffaut]
# 4495                                    [Comedy, Drama]                   []
# 4496  [Action &amp; Adventure, Drama, Horror, Scienc...       [Ridley Scott]
# 4497                 [Comedy, Drama, Kids &amp; Family]     [Chris Columbus]
# 4498                           [Action &amp; Adventure]                   []
#
# [4499 rows x 6 columns]

# %%
import numpy as np
scrappedData.fillna(value = np.nan, inplace = True)

# %%
scrappedData
# Out:
#                                    name audience critics          date  \
# 0              children_of_a_lesser_god       79      81   Oct 3, 1986
# 1                            changeland       66      63   Jun 7, 2019
# 2                    japanese_war_bride      NaN     NaN  Jan 29, 1952
# 3                                8_mile       54      75   Nov 8, 2002
# 4                                 ted_2       50      45  Jun 26, 2015
# ...                                 ...      ...     ...           ...
# 4494                  two_english_girls       82      86  Oct 15, 1972
# 4495                      3_generations       44      32   May 5, 2017
# 4496                    prometheus_2012       68      73   Jun 8, 2012
# 4497                      mrs_doubtfire       77      72  Nov 24, 1993
# 4498  national_treasure_book_of_secrets       67      36  Dec 21, 2007
#
#                                                   genre             director
# 0       [Drama, Musical &amp; Performing Arts, Romance]       [Randa Haines]
# 1                                       [Comedy, Drama]         [Seth Green]
# 2                                     [Classics, Drama]         [King Vidor]
# 3                                               [Drama]      [Curtis Hanson]
# 4                                              [Comedy]    [Seth MacFarlane]
# ...                                                 ...                  ...
# 4494  [Art House &amp; International, Documentary, D...  [François Truffaut]
# 4495                                    [Comedy, Drama]                   []
# 4496  [Action &amp; Adventure, Drama, Horror, Scienc...       [Ridley Scott]
# 4497                 [Comedy, Drama, Kids &amp; Family]     [Chris Columbus]
# 4498                           [Action &amp; Adventure]                   []
#
# [4499 rows x 6 columns]

# %%
scrappedData = scrappedData.astype({'audience' : 'float', 'critics' : 'float'})
scrappedData.dtypes
# Out:
# name         object
# audience    float64
# critics     float64
# date         object
# genre        object
# director     object
# dtype: object

# %%
from datetime import *
for x in range(scrappedData.shape[0]):
    if scrappedData.at[x, 'date'] is np.nan:
        newTime = datetime(1677,9,22)
    else:
        newTime = datetime.strptime(scrappedData.at[x, 'date'], '%b %d, %Y')
    scrappedData.at[x,'date'] = newTime
scrappedData
# Out:
#                                    name  audience  critics  \
# 0              children_of_a_lesser_god      79.0     81.0
# 1                            changeland      66.0     63.0
# 2                    japanese_war_bride       NaN      NaN
# 3                                8_mile      54.0     75.0
# 4                                 ted_2      50.0     45.0
# ...                                 ...       ...      ...
# 4494                  two_english_girls      82.0     86.0
# 4495                      3_generations      44.0     32.0
# 4496                    prometheus_2012      68.0     73.0
# 4497                      mrs_doubtfire      77.0     72.0
# 4498  national_treasure_book_of_secrets      67.0     36.0
#
#                      date                                              genre  \
# 0     1986-10-03 00:00:00    [Drama, Musical &amp; Performing Arts, Romance]
# 1     2019-06-07 00:00:00                                    [Comedy, Drama]
# 2     1952-01-29 00:00:00                                  [Classics, Drama]
# 3     2002-11-08 00:00:00                                            [Drama]
# 4     2015-06-26 00:00:00                                           [Comedy]
# ...                   ...                                                ...
# 4494  1972-10-15 00:00:00  [Art House &amp; International, Documentary, D...
# 4495  2017-05-05 00:00:00                                    [Comedy, Drama]
# 4496  2012-06-08 00:00:00  [Action &amp; Adventure, Drama, Horror, Scienc...
# 4497  1993-11-24 00:00:00                 [Comedy, Drama, Kids &amp; Family]
# 4498  2007-12-21 00:00:00                           [Action &amp; Adventure]
#
#                  director
# 0          [Randa Haines]
# 1            [Seth Green]
# 2            [King Vidor]
# 3         [Curtis Hanson]
# 4       [Seth MacFarlane]
# ...                   ...
# 4494  [François Truffaut]
# 4495                   []
# 4496       [Ridley Scott]
# 4497     [Chris Columbus]
# 4498                   []
#
# [4499 rows x 6 columns]

# %%
scrappedData = scrappedData.astype({'date' : 'datetime64'})
scrappedData.dtypes
# Out:
# name                object
# audience           float64
# critics            float64
# date        datetime64[ns]
# genre               object
# director            object
# dtype: object

# %%
import re
for x in range(scrappedData.shape[0]):
    if scrappedData.at[x, 'name'] is np.nan:
        pass
    else:
        scrappedData.at[x, 'name'] = re.subn('_',' ',scrappedData.at[x, 'name'])[0]

# %%
scrappedData
# Out:
#                                    name  audience  critics       date  \
# 0              children of a lesser god      79.0     81.0 1986-10-03
# 1                            changeland      66.0     63.0 2019-06-07
# 2                    japanese war bride       NaN      NaN 1952-01-29
# 3                                8 mile      54.0     75.0 2002-11-08
# 4                                 ted 2      50.0     45.0 2015-06-26
# ...                                 ...       ...      ...        ...
# 4494                  two english girls      82.0     86.0 1972-10-15
# 4495                      3 generations      44.0     32.0 2017-05-05
# 4496                    prometheus 2012      68.0     73.0 2012-06-08
# 4497                      mrs doubtfire      77.0     72.0 1993-11-24
# 4498  national treasure book of secrets      67.0     36.0 2007-12-21
#
#                                                   genre             director
# 0       [Drama, Musical &amp; Performing Arts, Romance]       [Randa Haines]
# 1                                       [Comedy, Drama]         [Seth Green]
# 2                                     [Classics, Drama]         [King Vidor]
# 3                                               [Drama]      [Curtis Hanson]
# 4                                              [Comedy]    [Seth MacFarlane]
# ...                                                 ...                  ...
# 4494  [Art House &amp; International, Documentary, D...  [François Truffaut]
# 4495                                    [Comedy, Drama]                   []
# 4496  [Action &amp; Adventure, Drama, Horror, Scienc...       [Ridley Scott]
# 4497                 [Comedy, Drama, Kids &amp; Family]     [Chris Columbus]
# 4498                           [Action &amp; Adventure]                   []
#
# [4499 rows x 6 columns]

# %%
cleanData = scrappedData[~scrappedData.audience.isnull() & ~scrappedData.critics.isnull()]

# %%
scrappedData.dtypes
# Out:
# name        object
# audience    object
# critics     object
# date        object
# genre       object
# director    object
# dtype: object

# %%
cleanData[ (cleanData.date >= datetime(2010,1,1,0,0)) & ((cleanData.audience - cleanData.critics) > 30) ]
# Out:
#                                      name  audience  critics       date  \
# 7                            the smurfs 2      56.0     14.0 2013-07-31
# 76                     jacobs ladder 2019      41.0      5.0 2019-08-23
# 83                            midway 2019      92.0     42.0 2019-11-08
# 98                      the lion of judah      62.0      0.0 2011-03-25
# 119   alvin and the chipmunks chipwrecked      51.0     12.0 2011-12-16
# ...                                   ...       ...      ...        ...
# 4249                               bright      84.0     28.0 2017-12-22
# 4251                          tulip fever      43.0     10.0 2017-09-01
# 4267                     dont let go 2019      79.0     39.0 2019-08-30
# 4294                   inconceivable 2017      63.0     31.0 2017-06-30
# 4393                  black and blue 2019      93.0     52.0 2019-10-25
#
#                                                  genre           director
# 7                                  [Animation, Comedy]     [Raja Gosnell]
# 76                    [Horror, Mystery &amp; Suspense]                 []
# 83                     [Action &amp; Adventure, Drama]  [Roland Emmerich]
# 98                      [Animation, Kids &amp; Family]                 []
# 119             [Animation, Comedy, Kids &amp; Family]    [Mike Mitchell]
# ...                                                ...                ...
# 4249                                           [Drama]       [David Ayer]
# 4251                                  [Drama, Romance]                 []
# 4267                          [Mystery &amp; Suspense]      [Jacob Estes]
# 4294                          [Mystery &amp; Suspense]                 []
# 4393  [Action &amp; Adventure, Mystery &amp; Suspense]      [Deon Taylor]
#
# [182 rows x 6 columns]

# %%
print(cleanData[ (cleanData.date >= datetime(2010,1,1,0,0)) & ((cleanData.audience - cleanData.critics) > 30) ].name.to_string())
# Out:
# 7                                            the smurfs 2
# 76                                     jacobs ladder 2019
# 83                                            midway 2019
# 98                                      the lion of judah
# 119                   alvin and the chipmunks chipwrecked
# 133                                            the upside
# 158                                    the wedding ringer
# 175                       king arthur legend of the sword
# 180                                    the miracle season
# 190                               madeas big happy family
# 202                                       gods not dead 2
# 203                                          believe 2016
# 206                       star wars the rise of skywalker
# 303                                            son of god
# 319                                     collateral beauty
# 328                                         barefoot 2014
# 338                                       vampire academy
# 395                                       one small hitch
# 421                                      the longest ride
# 430                                       hitman agent 47
# 432                                  miracles from heaven
# 433                                    the flowers of war
# 486                       the resurrection of gavin stone
# 490                                      super troopers 2
# 511                                  think like a man too
# 591                                       meet the blacks
# 614                                          dark phoenix
# 621                                   the case for christ
# 636                                  the single moms club
# 657                                        dracula untold
# 668                                       the river thief
# 671                          the vanishing of sidney hall
# 688                                                   axl
# 691                            men in black international
# 698                  the mortal instruments city of bones
# 710                                           grown ups 2
# 716                                            colombiana
# 730                                          blood ransom
# 780                        transformers age of extinction
# 817                     batman v superman dawn of justice
# 854                          the professor and the madman
# 943                                        need for speed
# 970                                           jigsaw 2017
# 986                                       passengers 2016
# 1053                                       winnie mandela
# 1103                                             warcraft
# 1133                                      just go with it
# 1135                                             man down
# 1151                      big mommas like father like son
# 1164                                         october baby
# 1172                        im in love with a church girl
# 1199                                   jack and jill 2011
# 1205                                  bitter harvest 2017
# 1226                                       im not ashamed
# 1227                                              blended
# 1231                                              taken 3
# 1233                                      the emoji movie
# 1239    hillarys america the secret history of the dem...
# 1286                          unbroken path to redemption
# 1335                                       identity thief
# 1342                                            max steel
# 1370                                    the darkest minds
# 1429                                        baggage claim
# 1431                           when the bough breaks 2016
# 1438                                   alita battle angel
# 1464                              hammer of the gods 2013
# 1493                                            a la mala
# 1524                                        scary movie 5
# 1553                                       countdown 2019
# 1567                                            unplanned
# 1617                                      best night ever
# 1621                                         hellboy 2019
# 1639                            when the game stands tall
# 1710                                    midnight sun 2018
# 1718                                   battle of the year
# 1735                                          priest 2011
# 1805                                        strange magic
# 1829                                          priest 1994
# 1830                                           gotti 2018
# 1864                                 the other woman 2014
# 1891                   godzilla king of the monsters 2019
# 1892                                           21 bridges
# 1931                                     the promise 2016
# 1950                                           annie 2014
# 1965                                 the space between us
# 1999                          maleficent mistress of evil
# 2001                                 the perfect guy 2015
# 2015                                        47 ronin 2013
# 2024                                        carbon nation
# 2046                               playing with fire 2019
# 2049                                  playmobil the movie
# 2056                                     the book of love
# 2067                                      the big wedding
# 2073                                  fifty shades darker
# 2107                                      my all american
# 2134                                               race 2
# 2182                               after the wedding 2019
# 2186                                     mothers day 2016
# 2201                                           venom 2018
# 2247                                   the gallows act ii
# 2318                               paul apostle of christ
# 2325                                       the shack 2017
# 2329                                       overboard 2018
# 2330                                           courageous
# 2345                                                 jexi
# 2346                                    a haunted house 2
# 2350                                        dirty grandpa
# 2364                                        the identical
# 2424                                        hunter killer
# 2433                                       a dogs purpose
# 2435                                   christmas eve 2015
# 2441                                     angel has fallen
# 2447                                           shaft 2000
# 2576                                          arctic dogs
# 2587                                           safe haven
# 2610                                        addicted 2014
# 2644                                           shaft 2019
# 2656                                         last knights
# 2666                                        hell and back
# 2670    gosnell the trial of americas biggest serial k...
# 2679                                               stuber
# 2748                                 back in the day 2014
# 2750      pirates of the caribbean dead men tell no tales
# 2769                                    the book of henry
# 2775                                         lets be cops
# 2794                                        the host 2013
# 2818                                           after 2019
# 2835                                         gun shy 2017
# 2894                                     the letters 2014
# 2928             13 hours the secret soldiers of benghazi
# 2937                                      death wish 2018
# 2948                                      forever my girl
# 2958                                        gods not dead
# 2978                                  waiting for forever
# 3003                                           glass 2019
# 3029                                       the best of me
# 3037                                    endless love 2014
# 3104                        the art of racing in the rain
# 3144                                      the choice 2016
# 3251                                               seberg
# 3264                                       a dogs journey
# 3359                alvin and the chipmunks the road chip
# 3377                                         ride along 2
# 3394                                       moms night out
# 3461                                     rambo last blood
# 3505                                            cats 2019
# 3512                                    the vatican tapes
# 3534                                             acrimony
# 3628                                                 poms
# 3662                                            dumbbells
# 3672                                   new years eve 2011
# 3681       temptation confessions of a marriage counselor
# 3688                                         hello herman
# 3726                                           persecuted
# 3739                                           ride along
# 3750                                     life itself 2018
# 3755                                     left behind 2014
# 3785                                            overcomer
# 3812                                   the lion king 2019
# 3813                                           jamesy boy
# 3837                         same kind of different as me
# 3856                                      a haunted house
# 3878                                       abduction 2011
# 3924                                        old fashioned
# 3955                                atlas shrugged part i
# 3958                                     the masked saint
# 3970                                        the goldfinch
# 3973                                       stonewall 2015
# 4006                                      peppermint 2018
# 4029                                  the baytown outlaws
# 4030                                 the christmas candle
# 4053                                       country strong
# 4099                    gods not dead a light in darkness
# 4107                                     the kitchen 2019
# 4154                                       i frankenstein
# 4174                                    the good catholic
# 4217                                         aladdin 2019
# 4249                                               bright
# 4251                                          tulip fever
# 4267                                     dont let go 2019
# 4294                                   inconceivable 2017
# 4393                                  black and blue 2019

# %%
scrappedData.to_pickle('all_data_clean.pkl', protocol = 4)

# %%
sqlSearchStr = "SELECT * FROM ratings WHERE Title LIKE "
new = 'August Rush%'
for i in range(superclean.name):
    appendStr = "'" + superclean.name.iloc[i]+"%'"
    sqlDF = sc.sql(sqlSearchStr + appendStr)
